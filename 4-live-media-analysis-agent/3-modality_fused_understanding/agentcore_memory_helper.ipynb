# %% [markdown]
# # AgentCore Memory - Create and Delete Test
#
# This notebook demonstrates how to create and delete AWS Bedrock AgentCore memory sessions.
#
# ## Features
# - Create memory with custom name
# - View memory details
# - Delete memory
# - Test context manager usage

# %%
from bedrock_agentcore.memory import MemoryClient
from bedrock_agentcore.memory.constants import StrategyType

memory_client = MemoryClient(region_name='us-west-2')

video_analysis_mem_id ='video_analysis_memory-V7TzlbGdRm'
actor_id = "lvu"
video_analysis_session_id = "video-analysis"

transcript_mem_id ='live_transcript_memory-qua9D5EFQK'
actor_id = "lvu"
trans_session_id = "transcripts"

live_analysis_events = memory_client.list_events(
    memory_id=video_analysis_mem_id,
    actor_id=actor_id,
    session_id=video_analysis_session_id,
    max_results=100
)
live_analysis_events
# Out:
# [{'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969676290#7d642888',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 44, 36, 290000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this fifteenth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "new_topic",\n      "id": "t4",\n      "chapter_id": "h3",\n      "topic_summary": "The detective arrives at El Matador beach where two vintage police cars (1940s black sedans) are parked on sandy ground with an overcast sky. Initially the cars are empty, but then a figure appears beside one of the vehicles - likely another detective or police officer who has arrived at the scene. The detective from the previous scenes approaches his car wearing his signature fedora hat and suit, suggesting this is now an official police investigation of the disappearances. The scene establishes that law enforcement is taking the supernatural events seriously enough to send multiple officers to the location.",\n      "start_time": 280.0,\n      "end_time": 300.0,\n      "chunks": [14],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 15,\n    "processing_notes": "This chunk shows a new scene with two vintage police cars parked at what appears to be El Matador beach. The filmstrip shows a progression where initially the cars are empty (frames 1-8), then a figure appears beside one of the vehicles (frames 9-15), and finally there\'s a shot change at 295.50s to a close-up of the detective in his fedora hat and suit approaching his car (frames 16-20). The visual style maintains the noir aesthetic with muted colors and period-appropriate vehicles. No dialogue is present in this chunk. The scene suggests the investigation has become official with multiple law enforcement officers at the location where the disappearances occurred."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969657919#bedfb84e',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 44, 17, 919000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this fourteenth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t3",\n      "topic_summary": "The detective\'s supernatural encounter intensifies as he sees the mysterious woman with alabaster skin in his rearview mirror. His expression shows growing terror as he realizes the supernatural entity described by the witness has found him. The scene then transitions dramatically at 272.50s to show the detective\'s vintage car arriving at a desolate coastal location - likely El Matador beach. The car is shown parked on sandy ground with an overcast sky, suggesting he has reached the destination where the disappearances occurred and where the mysterious woman was sighted.",\n      "end_time": 280.0,\n      "chunks": [9, 10, 11, 12, 13],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 14,\n    "processing_notes": "Major scene transition detected at 272.50s (frame 13) with a significant visual shift from the interior car scene with the woman in the mirror to an exterior shot of the detective\'s vintage car parked at what appears to be the investigation destination. The filmstrip shows two distinct sequences: frames 1-12 continue the supernatural encounter with the woman\'s face in the rearview mirror and the detective\'s shocked reaction, while frames 13-20 show the vintage car (appears to be a 1940s black sedan) parked on sandy ground near the coast with an overcast sky. The second sequence shows multiple angles of the parked car, suggesting the detective has arrived at El Matador beach where the mysterious events occurred. No dialogue is present in this chunk, indicating a transitional sequence."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969640768#3e2e6f03',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 44, 0, 768000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this thirteenth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t3",\n      "topic_summary": "The detective drives along a coastal road when supernatural events begin to unfold. As he continues mentally reviewing the witness testimony, the weather suddenly changes with rain appearing on the windshield. In a shocking moment, he sees the mysterious woman with alabaster skin in his rearview mirror. The detective\'s expression shifts from concentration to shock and fear as he realizes the supernatural entity described by the witness has found him in his car. His face shows growing terror as he processes what he\'s seeing - the woman from the witness account is now directly behind him, \'staring right at him, not moving,\' exactly as described in the testimony.",\n      "end_time": 259.546,\n      "chunks": [9, 10, 11, 12],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 13,\n    "processing_notes": "This chunk continues the supernatural encounter that began in the previous chunk. The filmstrip shows a dramatic sequence with three distinct shot patterns: frames 1-13 show the detective in his car looking increasingly concerned, frames 14-16 show the woman\'s face in the rearview mirror (confirming the supernatural presence), and frames 17-20 show the detective\'s shocked reaction as he realizes what\'s happening. Major shot changes at 253.0s (mirror view) and 256.5s (reaction shot). The audio narration directly parallels the visuals with descriptions of the woman \'in a long white dress with alabaster skin\' who is \'staring right up at him, not moving.\' The detective\'s expression of shock and disbelief matches the final line: \'Now I don\'t know what to believe. I know I sure don\'t want to believe him.\'"\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969626032#b3065181',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 43, 46, 32000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this twelfth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t3",\n      "topic_summary": "The detective drives along a coastal road in his vintage car, continuing to mentally review the witness testimony about the mysterious disappearances. As he drives, the weather suddenly begins to change - raindrops appear on the windshield, matching the witness\'s account of sudden darkness and strange weather. In a dramatic moment, the detective sees a woman\'s face appear in his rearview mirror, suggesting the supernatural presence described by the witness has found him. The scene builds tension through the visual transition from normal driving conditions to the supernatural encounter.",\n      "end_time": 240.516,\n      "chunks": [9, 10, 11],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 12,\n    "processing_notes": "Continuing the investigation journey scene with a significant supernatural development. The filmstrip shows the detective driving (frames 1-17) with a dramatic shot change at 237.0s when raindrops suddenly appear on the windshield, coinciding with the narration about sudden darkness and strange weather. Another major shot change at 238.5s reveals a woman\'s face appearing in the rearview mirror (frames 19-20), suggesting the supernatural presence has found the detective. This visual revelation perfectly aligns with the audio narration about the mysterious woman from the witness account. The scene effectively transitions from investigation to supernatural encounter."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969611668#bafa7e5b',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 43, 31, 668000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this eleventh chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t3",\n      "topic_summary": "The detective drives along a coastal mountain highway in a vintage car, heading toward El Matador beach to investigate the mysterious disappearances. The scene shows aerial views of the car traveling through rugged terrain, followed by close-up shots of the detective inside the vehicle. As he drives, he mentally reviews the case details, recalling key elements from the witness testimony about the disappearances and the mysterious woman. The period-appropriate vehicle and winding coastal road establish the journey to the investigation site.",\n      "end_time": 220.0,\n      "chunks": [9, 10],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 11,\n    "processing_notes": "Continuing the investigation journey scene that began at the end of the previous chunk. The filmstrip shows two main visual sequences: aerial shots of a vintage car driving along a coastal mountain highway (frames 1-5), followed by interior shots of the detective driving (frames 6-20). Shot change detected at 205.50s marks the transition from aerial view to inside the car. The audio features the detective mentally reviewing key elements of the case as he drives. The detective is wearing a suit with tie, driving what appears to be a 1940s-era vehicle, consistent with the film noir aesthetic established earlier."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969579096#4083448b',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 42, 59, 96000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this tenth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t2",\n      "topic_summary": "A noir-style detective scene where two detectives discuss mysterious disappearances near El Matador and Big Rock. The older detective reveals a witness account that becomes increasingly supernatural: a man walking his dog saw someone on a rock, then suddenly the sky darkened with thunder and lightning. The man vanished and was replaced by a beautiful woman in a white dress with \'alabaster skin\' who seemed \'from some other time, some other place.\' The witness fled as the weather worsened. The scene concludes with the older detective instructing the younger detective to \'go up there and find that woman,\' suggesting a supernatural investigation.",\n      "end_time": 198.776,\n      "chunks": [1, 2, 3, 4, 5, 6, 7, 8, 9],\n      "confidence": 9\n    },\n    {\n      "type": "new_chapter",\n      "id": "h3",\n      "chapter": "Investigation Journey",\n      "confidence": 8\n    },\n    {\n      "type": "new_topic",\n      "id": "t3",\n      "chapter_id": "h3",\n      "topic_summary": "The scene transitions from the detective\'s office to an outdoor setting showing a car driving along a coastal highway. This appears to be the beginning of the detective\'s journey to investigate the mysterious disappearances at El Matador beach and find the woman described by the witness. The road winds through hills along what is likely the Pacific Coast Highway heading toward the location where the supernatural events occurred.",\n      "start_time": 198.776,\n      "end_time": 200.0,\n      "chunks": [9],\n      "confidence": 8\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 10,\n    "processing_notes": "Major scene transition detected at 198.776s with both visual and content shift from the noir detective office to an outdoor coastal road scene. The filmstrip shows the conclusion of the office scene with the older detective giving the assignment to find the mysterious woman, followed by a shot change to an aerial view of a car driving on a coastal highway. This marks the beginning of a new chapter as the story moves from investigation planning to active field investigation. The door sign reading \'DETECTIVE CARLOS\' is visible in frames with the younger detective before the transition."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969557842#51a8e801',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 42, 37, 842000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this ninth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t2",\n      "topic_summary": "A noir-style detective scene where two detectives discuss mysterious disappearances near El Matador and Big Rock. The older detective reveals a witness account that becomes increasingly supernatural: a man walking his dog saw someone on a large rock formation, then suddenly the sky darkened with thunder and lightning \'coming from nowhere.\' When the witness looked back, the man had vanished and was replaced by a woman in a white dress with \'alabaster skin\' who stared directly up at him. The scene maintains its noir aesthetic with dramatic lighting through window blinds casting shadows across the detective\'s office, building tension as the supernatural elements of the case are revealed.",\n      "end_time": 178.426,\n      "chunks": [1, 2, 3, 4, 5, 6, 7, 8],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 9,\n    "processing_notes": "Continuing the noir detective scene with the older detective describing the witness account. Shot changes at 166.0s and 176.0s show transitions between the detectives and a wider shot of both in the office. The narrative takes a more explicitly supernatural turn as the witness describes thunder and lightning appearing from nowhere, and the man on the rock being replaced by a mysterious woman in a white dress with \'alabaster skin\' who stared directly at the witness. The LAPD sign is visible (reversed) in the window glass, and the wall clock continues to be visible in shots with the older detective. The scene builds tension through both visual noir elements and the increasingly supernatural narrative."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969532960#206c6fce',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 42, 12, 960000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this eighth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t2",\n      "topic_summary": "A noir-style detective scene where two detectives discuss mysterious disappearances near El Matador and Big Rock. The older detective reveals a witness account of the last disappearance: a man walking his dog saw someone on a large rock formation that resembles \'a mythic sea creature.\' The witness was puzzled how anyone could climb the rock, and noticed the man was searching for something. Suddenly, it became extremely dark and \'bombs started going off in the air.\' The scene maintains its noir aesthetic with dramatic lighting through window blinds casting shadows across the detective\'s office, suggesting supernatural elements to the disappearances.",\n      "end_time": 160.786,\n      "chunks": [1, 2, 3, 4, 5, 6, 7],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 8,\n    "processing_notes": "Continuing the noir detective scene with the older detective describing the witness account. The filmstrip shows primarily the older detective speaking, with dramatic lighting through window blinds creating the classic noir aesthetic. A wall clock is visible in the background. The narrative takes a supernatural turn as the witness describes the scene becoming \'really, really dark\' suddenly and \'bombs going off in the air.\' The visual style remains consistent with previous chunks, maintaining the tense atmosphere as the supernatural elements of the case are revealed."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969516891#a0760318',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 41, 56, 891000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this seventh chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t2",\n      "topic_summary": "A noir-style detective scene where two detectives discuss mysterious disappearances near El Matador and Big Rock. The older detective reveals there was a witness to the last disappearance, initially dismissed as \'nuts\' but now considered credible (\'a goddamn Eagle Scout\'). The witness describes walking his dog along the bluffs above El Matador beach and seeing a man on a large rock separated from the mainland - a rock he describes as looking like \'a mythic sea creature.\' The scene continues to alternate between close-ups of both detectives in their dimly lit office with window blinds casting dramatic shadows, creating a classic film noir aesthetic.",\n      "end_time": 141.026,\n      "chunks": [1, 2, 3, 4, 5, 6],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 7,\n    "processing_notes": "Continuing the noir detective scene with dialogue about the witness account. Shot changes at 120.0s, 124.0s, 131.0s, and 137.0s show transitions between the two detectives as the older detective finally reveals what the witness saw. The scene maintains visual continuity with the noir aesthetic - window blinds casting shadows, wall clock visible, and the \'LAPD\' sign visible (reversed) in the window glass. The door sign reading \'DETECTIVE CARLOS\' is visible in frames with the younger detective. The narrative builds tension as the witness account begins to reveal supernatural elements with the description of the rock as \'a mythic sea creature.\'"\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969493361#9d7b7300',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 41, 33, 361000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this sixth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t2",\n      "topic_summary": "A noir-style detective scene where two detectives discuss mysterious disappearances near El Matador and Big Rock. The older detective reveals there was a witness to the last disappearance, initially dismissed as \'nuts\' but now considered credible (\'a goddamn Eagle Scout\'). The detectives debate theories about the case, with the older detective reluctant to believe the witness\'s account despite finding no other explanation. The scene continues to alternate between close-ups of both detectives in their dimly lit office with window blinds casting dramatic shadows, creating a classic film noir aesthetic.",\n      "end_time": 120.696,\n      "chunks": [1, 2, 3, 4, 5],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 6,\n    "processing_notes": "Continuing the noir detective scene with dialogue about the investigation. Shot changes at 100.5s, 103.0s, 109.0s, and 114.5s show transitions between the two detectives as they discuss the witness. The conversation reveals a key development - there was a witness to the last disappearance who the older detective initially thought was \'nuts\' but now considers credible. Visual elements maintain the noir aesthetic with window blinds casting shadows, desk lamp, wall clock, and the \'LAPD\' sign visible (reversed) in the window glass. The scene builds tension as the older detective is reluctant to share what the witness reported."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969473079#48b2154b',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 41, 13, 79000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this fifth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t2",\n      "topic_summary": "A noir-style detective scene where two characters discuss mysterious disappearances near El Matador and Big Rock. The detective explains these aren\'t mob hits despite Mickey Cohen\'s history in the area. The victims were ordinary citizens with no criminal connections except one with an old DUI, and all were divorced. The younger detective suggests suicide - \'the long, cold, slow swim to China\' - but the older detective dismisses this theory, noting there are no bodies and someone was present when the last victim disappeared. The scene alternates between close-ups of both detectives in their dimly lit office with window blinds casting dramatic shadows.",\n      "end_time": 99.866,\n      "chunks": [1, 2, 3, 4],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 5,\n    "processing_notes": "Continuing the noir detective scene with dialogue about the investigation. Shot changes at 81.0s and 92.0s show transitions between the two detectives as they discuss theories about the disappearances. The younger detective suggests suicide while the older detective dismisses this, noting there are no bodies and a witness was present at the last disappearance. Visual elements include the continued noir aesthetic with window blinds casting shadows, desk lamp, and the \'LAPD\' sign visible (reversed) in the window glass. A wall clock is also visible in the frames with the older detective."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969452452#be90a64d',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 40, 52, 452000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this fourth chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t2",\n      "topic_summary": "A noir-style detective scene where two characters discuss mysterious disappearances near El Matador and Big Rock. The detective explains these aren\'t mob hits despite Mickey Cohen\'s history in the area. The victims were ordinary citizens - a schoolteacher, insurance salesman, and retiree - with no criminal connections except one with an old DUI. The only common factor is they were all divorced. The scene shows both characters in a dimly lit office with window blinds casting shadows, and includes a shot change to a younger detective at a desk with a lamp, where they exchange banter about the danger of the investigation.",\n      "end_time": 80.466,\n      "chunks": [1, 2, 3],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 4,\n    "processing_notes": "Continuing the noir detective scene with dialogue about the investigation. Major shot change detected at 72.0s transitions from the older detective to a younger detective/officer at a desk with a lamp. The conversation reveals more details about the victims (all divorced, no criminal connections) and ends with some dark humor about the danger of investigating the case. Visual elements include office with window blinds, desk lamp, and what appears to be an \'LAPD\' sign visible in the background of the younger detective\'s office."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969435325#569c62db',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 40, 35, 325000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this third chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t2",\n      "topic_summary": "A noir-style detective scene where two characters discuss mysterious disappearances near El Matador and Big Rock. One character mentions Mickey Cohen taking his associates there, suggesting mob connections. The detective clarifies these aren\'t mob hits, as the victims were ordinary citizens - a schoolteacher, insurance salesman, and retiree. The scene shows both characters in a dimly lit office with window blinds casting shadows, and includes photographs of the missing men displayed on a desk.",\n      "end_time": 58.846,\n      "chunks": [1, 2],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 3,\n    "processing_notes": "Continuing the noir detective scene with dialogue about the disappearance case. Shot change detected at 49.50s shows transition from dialogue to photographs of the missing men. The conversation reveals these aren\'t mob hits but disappearances of ordinary citizens. Visual elements include office with window blinds, desk lamp, and photographs of three men. The \'LAPD\' text is visible (reversed) in the window glass, confirming police investigation context."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969414253#c325836c',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 40, 14, 253000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this second chunk based on the filmstrip, transcript, and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "update_topic",\n      "id": "t1",\n      "topic_summary": "Historical footage of Los Angeles in 1947 showing various city streets and locations, including the Meridian building with vintage cars parked outside. The footage captures the architectural style and urban landscape of post-war Los Angeles with period vehicles and storefronts visible throughout the sequence.",\n      "end_time": 20.5,\n      "chunks": [0]\n    },\n    {\n      "type": "new_chapter",\n      "id": "h2",\n      "chapter": "Film Noir Detective Scene",\n      "confidence": 9\n    },\n    {\n      "type": "new_topic",\n      "id": "t2",\n      "chapter_id": "h2",\n      "topic_summary": "A noir-style scene showing a detective or officer in a dimly lit office with window blinds casting shadows. The person appears to be smoking while discussing a case involving disappearances near El Matador and Big Rock, with mention of Mickey Cohen taking his associates there. The scene transitions from one character to another in what appears to be an interrogation or discussion about criminal activities.",\n      "start_time": 20.5,\n      "end_time": 40.0,\n      "chunks": [1],\n      "confidence": 9\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 2,\n    "processing_notes": "Major scene transition detected at 20.5s with both visual and content shift from historical footage to a film noir detective scene. Another shot change at 30.5s shows transition between characters in the same scene. Transcript begins at 27.026s with dialogue about disappearances and references to Mickey Cohen, matching the noir detective visual context. Text visible in frames includes \'Meridian\' and \'LAPD\' (reversed in window reflection)."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'video_analysis_memory-V7TzlbGdRm',
#   'actorId': 'lvu',
#   'sessionId': 'video-analysis',
#   'eventId': '0000001760969393723#d72d1cbd',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 39, 53, 723000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': 'I\'ll analyze this first chunk of the video based on the filmstrip and shot change information provided.\n\n```json\n{\n  "actions": [\n    {\n      "type": "new_chapter",\n      "id": "h1",\n      "chapter": "Historical Los Angeles (1947)",\n      "confidence": 5\n    },\n    {\n      "type": "new_topic",\n      "id": "t1",\n      "chapter_id": "h1",\n      "topic_summary": "Historical footage of Los Angeles in 1947 showing various city streets and locations. The filmstrip displays different views of downtown Los Angeles with vintage cars, buildings, and urban scenes. Several locations are shown including busy streets with traffic, commercial buildings, and what appears to be the Hollywood Hotel. The footage captures the architectural style and urban landscape of post-war Los Angeles with period vehicles and storefronts visible throughout the sequence.",\n      "start_time": 0.0,\n      "end_time": 20.0,\n      "chunks": [0],\n      "confidence": 5\n    }\n  ],\n  "analysis_status": {\n    "total_chunks_processed": 1,\n    "processing_notes": "Analysis based solely on filmstrip and shot change data (no transcript available). Multiple shot changes detected within this historical footage showing different locations in 1947 Los Angeles. Text visible in frames includes \'Los Angeles 1947\' and \'HOLLYWOOD HOTEL\'. Confidence is low due to lack of audio transcript."\n  }\n}\n```'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}}]

# %%
transcript_events = memory_client.list_events(
    memory_id=transcript_mem_id,
    actor_id=actor_id,
    session_id=trans_session_id,
    max_results=100
)
transcript_events
# Out:
# [{'memoryId': 'live_transcript_memory-qua9D5EFQK',
#   'actorId': 'lvu',
#   'sessionId': 'transcripts',
#   'eventId': '0000001760969651147#3d26fac3',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 44, 11, 147000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': '[\n  {\n    "sentence": "When he looks back at the rock the guy\'s gone but there\'s a woman there,",\n    "start_time": 242.376,\n    "end_time": 247.036,\n    "timestamp": "19:43:24"\n  },\n  {\n    "sentence": "in a long white dress with alabaster skin.",\n    "start_time": 247.326,\n    "end_time": 249.996,\n    "timestamp": "19:43:24"\n  },\n  {\n    "sentence": "and she\'s staring right up at him,",\n    "start_time": 250.536,\n    "end_time": 252.636,\n    "timestamp": "19:43:28"\n  },\n  {\n    "sentence": "not moving.",\n    "start_time": 252.806,\n    "end_time": 253.836,\n    "timestamp": "19:43:28"\n  },\n  {\n    "sentence": "Now I don\'t know what to believe I know I sure don\'t want to believe him.",\n    "start_time": 255.176,\n    "end_time": 259.546,\n    "timestamp": "19:43:34"\n  }\n]'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'live_transcript_memory-qua9D5EFQK',
#   'actorId': 'lvu',
#   'sessionId': 'transcripts',
#   'eventId': '0000001760969595430#1f0ab2b2',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 43, 15, 430000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': '[\n  {\n    "sentence": "a witness,",\n    "start_time": 214.946,\n    "end_time": 215.656,\n    "timestamp": "19:42:52"\n  },\n  {\n    "sentence": "yeah,",\n    "start_time": 216.106,\n    "end_time": 216.186,\n    "timestamp": "19:42:52"\n  },\n  {\n    "sentence": "a witness.",\n    "start_time": 216.346,\n    "end_time": 217.296,\n    "timestamp": "19:42:52"\n  },\n  {\n    "sentence": "He said that he was up there walking his dog along those bluffs above El Matador,",\n    "start_time": 218.066,\n    "end_time": 222.236,\n    "timestamp": "19:42:58
\n  }\n]'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}},
#  {'memoryId': 'live_transcript_memory-qua9D5EFQK',
#   'actorId': 'lvu',
#   'sessionId': 'transcripts',
#   'eventId': '0000001760969409722#a5a05e9d',
#   'eventTimestamp': datetime.datetime(2025, 10, 20, 19, 40, 9, 722000, tzinfo=tzlocal()),
#   'payload': [{'conversational': {'content': {'text': '[\n  {\n    "sentence": "So these guys just disappeared Yeah,",\n    "start_time": 27.026,\n    "end_time": 31.286,\n    "timestamp": "19:39:49"\n  },\n  {\n    "sentence": "on that stretch of road right above El Matador.",\n    "start_time": 31.646,\n    "end_time": 34.436,\n    "timestamp": "19:39:49"\n  },\n  {\n    "sentence": "You know it What\'s Big rock That\'s right.",\n    "start_time": 35.176,\n    "end_time": 38.366,\n    "timestamp": "19:39:53"\n  },\n  {\n    "sentence": "Yeah Mickey Cohen used to take his associates out there.",\n    "start_time": 38.526,\n    "end_time": 43.076,\n    "timestamp": "19:39:58"\n  },\n  {\n    "sentence": "bid him a bon voyage Mob hits?",\n    "start_time": 43.526,\n    "end_time": 46.546,\n    "timestamp": "19:40:09"\n  },\n  {\n    "sentence": "No,",\n    "start_time": 46.566,\n    "end_time": 46.676,\n    "timestamp": "19:40:09"\n  },\n  {\n    "sentence": "not this time.",\n    "start_time": 46.766,\n    "end_time": 47.686,\n    "timestamp": "19:40:09"\n  },\n  {\n    "sentence": "One of these guys is a schoolteacher.",\n    "start_time": 48.076,\n    "end_time": 50.116,\n    "timestamp": "19:40:09"\n  },\n  {\n    "sentence": "Next guy,",\n    "start_time": 50.766,\n    "end_time": 51.176,\n    "timestamp": "19:40:09"\n  },\n  {\n    "sentence": "he sold insurance.",\n    "start_time": 51.186,\n    "end_time": 52.466,\n    "timestamp": "19:40:09"\n  }\n]'},
#      'role': 'ASSISTANT'}}],
#   'branch': {'name': 'main'}}]

# %% [markdown]
# ## Delete Transcript Events
#
# Delete individual transcript events by event ID using boto3 client

# %%
import boto3

# Create boto3 client for bedrock-agent-runtime
bedrock_agent_client = boto3.client('bedrock-agentcore', region_name='us-west-2')

# Delete transcript events one by one
for event in transcript_events:
    event_id = event['eventId']
    print(f"Deleting transcript event: {event_id}")
    
    response = bedrock_agent_client.delete_event(
        memoryId=transcript_mem_id,
        sessionId=trans_session_id,
        eventId=event_id,
        actorId=actor_id
    )
    print(f"  Response: {response}")
# Out:
# Deleting transcript event: 0000001760944722692#48b4b5db
#   Response: {'ResponseMetadata': {'RequestId': '6ff57d5d-acc6-461b-ad6f-8ee3152ad4f2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:47 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '6ff57d5d-acc6-461b-ad6f-8ee3152ad4f2'}, 'RetryAttempts': 0}, 'eventId': '0000001760944722692#48b4b5db'}
# Deleting transcript event: 0000001760944658125#fb806380
#   Response: {'ResponseMetadata': {'RequestId': '9216303f-6353-431a-94a8-a5953dd3e502', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:47 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '9216303f-6353-431a-94a8-a5953dd3e502'}, 'RetryAttempts': 0}, 'eventId': '0000001760944658125#fb806380'}
# Deleting transcript event: 0000001760944635106#f25b1f23
#   Response: {'ResponseMetadata': {'RequestId': '3ce0bcd1-c1b1-4c92-8f88-ace96f9b6e5a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:47 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '3ce0bcd1-c1b1-4c92-8f88-ace96f9b6e5a'}, 'RetryAttempts': 0}, 'eventId': '0000001760944635106#f25b1f23'}
# Deleting transcript event: 0000001760944600533#16df6988
#   Response: {'ResponseMetadata': {'RequestId': 'c8e571cf-34f4-4429-aabc-5203c59605e0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:48 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'c8e571cf-34f4-4429-aabc-5203c59605e0'}, 'RetryAttempts': 0}, 'eventId': '0000001760944600533#16df6988'}
# Deleting transcript event: 0000001760944579631#f7a308cf
#   Response: {'ResponseMetadata': {'RequestId': '14e0ae9e-771f-4855-ae40-59ebd16dc790', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:48 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '14e0ae9e-771f-4855-ae40-59ebd16dc790'}, 'RetryAttempts': 0}, 'eventId': '0000001760944579631#f7a308cf'}
# Deleting transcript event: 0000001760944555885#527c425d
#   Response: {'ResponseMetadata': {'RequestId': '286351bf-7eb8-4853-b2a0-855967b89c31', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:48 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '286351bf-7eb8-4853-b2a0-855967b89c31'}, 'RetryAttempts': 0}, 'eventId': '0000001760944555885#527c425d'}
# Deleting transcript event: 0000001760944542463#1d1a9c24
#   Response: {'ResponseMetadata': {'RequestId': '4bccb003-e653-438a-b60d-3358867bf52d', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:49 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '4bccb003-e653-438a-b60d-3358867bf52d'}, 'RetryAttempts': 0}, 'eventId': '0000001760944542463#1d1a9c24'}
# Deleting transcript event: 0000001760944517489#d98a0636
#   Response: {'ResponseMetadata': {'RequestId': 'e30bca37-771c-49e6-9e6d-a7b2d1debd8c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:49 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'e30bca37-771c-49e6-9e6d-a7b2d1debd8c'}, 'RetryAttempts': 0}, 'eventId': '0000001760944517489#d98a0636'}
# Deleting transcript event: 0000001760944500639#35984efb
#   Response: {'ResponseMetadata': {'RequestId': '5510b83f-8e43-4318-9a8d-a3871bbcb745', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:49 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '5510b83f-8e43-4318-9a8d-a3871bbcb745'}, 'RetryAttempts': 0}, 'eventId': '0000001760944500639#35984efb'}
# Deleting transcript event: 0000001760944492267#d60f4653
#   Response: {'ResponseMetadata': {'RequestId': '9d9d8ff5-6270-4720-9bae-f5690a115510', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:49 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '9d9d8ff5-6270-4720-9bae-f5690a115510'}, 'RetryAttempts': 0}, 'eventId': '0000001760944492267#d60f4653'}
# Deleting transcript event: 0000001760944472355#3cbc277c
#   Response: {'ResponseMetadata': {'RequestId': '09d25d4f-b964-4081-853c-b155ca374dc2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:50 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '09d25d4f-b964-4081-853c-b155ca374dc2'}, 'RetryAttempts': 0}, 'eventId': '0000001760944472355#3cbc277c'}

# %%
# Verify transcript events were deleted
remaining_transcript_events = memory_client.list_events(
    memory_id=transcript_mem_id,
    actor_id=actor_id,
    session_id=trans_session_id,
    max_results=10
)
print(f"Remaining transcript events: {len(remaining_transcript_events)}")
remaining_transcript_events
# Out:
# Remaining transcript events: 0
# []

# %% [markdown]
# ## Delete Video Analysis Events
#
# Delete individual video analysis events by event ID using boto3 client

# %%
# Delete video analysis events one by one
for event in live_analysis_events:
    event_id = event['eventId']
    print(f"Deleting video analysis event: {event_id}")
    
    response = bedrock_agent_client.delete_event(
        memoryId=video_analysis_mem_id,
        sessionId=video_analysis_session_id,
        eventId=event_id,
        actorId=actor_id
    )
    print(f"  Response: {response}")
# Out:
# Deleting video analysis event: 0000001760944745431#26a1c91c
#   Response: {'ResponseMetadata': {'RequestId': 'ec1cf720-d894-424a-b627-589fafee6547', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:53 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'ec1cf720-d894-424a-b627-589fafee6547'}, 'RetryAttempts': 0}, 'eventId': '0000001760944745431#26a1c91c'}
# Deleting video analysis event: 0000001760944730329#ac979e24
#   Response: {'ResponseMetadata': {'RequestId': 'f92f4270-1701-46f8-8e90-c01c1130d453', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:53 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'f92f4270-1701-46f8-8e90-c01c1130d453'}, 'RetryAttempts': 0}, 'eventId': '0000001760944730329#ac979e24'}
# Deleting video analysis event: 0000001760944716485#3deb3ad0
#   Response: {'ResponseMetadata': {'RequestId': '7a52a4d6-a9a0-4d52-9461-14378772cf4a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:53 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '7a52a4d6-a9a0-4d52-9461-14378772cf4a'}, 'RetryAttempts': 0}, 'eventId': '0000001760944716485#3deb3ad0'}
# Deleting video analysis event: 0000001760944698934#69b74d51
#   Response: {'ResponseMetadata': {'RequestId': '945c0887-df23-4655-88b4-a1b03630012d', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:53 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '945c0887-df23-4655-88b4-a1b03630012d'}, 'RetryAttempts': 0}, 'eventId': '0000001760944698934#69b74d51'}
# Deleting video analysis event: 0000001760944681743#ed59c1a3
#   Response: {'ResponseMetadata': {'RequestId': '3bec9120-b0a6-4e01-a0bb-9750c5a4ddfb', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:54 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '3bec9120-b0a6-4e01-a0bb-9750c5a4ddfb'}, 'RetryAttempts': 0}, 'eventId': '0000001760944681743#ed59c1a3'}
# Deleting video analysis event: 0000001760944649350#afc5bdce
#   Response: {'ResponseMetadata': {'RequestId': '024dfdba-5d6e-4712-81f0-b77ba7acd338', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:54 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '024dfdba-5d6e-4712-81f0-b77ba7acd338'}, 'RetryAttempts': 0}, 'eventId': '0000001760944649350#afc5bdce'}
# Deleting video analysis event: 0000001760944623300#c0fcc127
#   Response: {'ResponseMetadata': {'RequestId': 'f5324246-4e61-434d-8565-8a673bc146db', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:54 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'f5324246-4e61-434d-8565-8a673bc146db'}, 'RetryAttempts': 0}, 'eventId': '0000001760944623300#c0fcc127'}
# Deleting video analysis event: 0000001760944600085#54d6bf04
#   Response: {'ResponseMetadata': {'RequestId': '2caab445-6df1-4e2f-9bec-f53c35c781bd', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:55 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '2caab445-6df1-4e2f-9bec-f53c35c781bd'}, 'RetryAttempts': 0}, 'eventId': '0000001760944600085#54d6bf04'}
# Deleting video analysis event: 0000001760944580599#9d6b7387
#   Response: {'ResponseMetadata': {'RequestId': 'e919b8d0-9b61-420d-a2f7-5988df4f1a4a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:55 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'e919b8d0-9b61-420d-a2f7-5988df4f1a4a'}, 'RetryAttempts': 0}, 'eventId': '0000001760944580599#9d6b7387'}
# Deleting video analysis event: 0000001760944560751#ca8ff1d6
#   Response: {'ResponseMetadata': {'RequestId': '6c83698d-7751-4dc4-97d7-1c221debc571', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:55 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '6c83698d-7751-4dc4-97d7-1c221debc571'}, 'RetryAttempts': 0}, 'eventId': '0000001760944560751#ca8ff1d6'}
# Deleting video analysis event: 0000001760944541038#b742f29a
#   Response: {'ResponseMetadata': {'RequestId': 'a5a330e3-b5d9-44a2-80ff-292d4b227a24', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:55 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'a5a330e3-b5d9-44a2-80ff-292d4b227a24'}, 'RetryAttempts': 0}, 'eventId': '0000001760944541038#b742f29a'}
# Deleting video analysis event: 0000001760944518785#660f459e
#   Response: {'ResponseMetadata': {'RequestId': 'd45f8022-da72-4e54-b0f0-16bcadbac089', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:56 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'd45f8022-da72-4e54-b0f0-16bcadbac089'}, 'RetryAttempts': 0}, 'eventId': '0000001760944518785#660f459e'}
# Deleting video analysis event: 0000001760944496960#92110448
#   Response: {'ResponseMetadata': {'RequestId': 'efcd187e-ff48-4230-8690-769852860a1e', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:56 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': 'efcd187e-ff48-4230-8690-769852860a1e'}, 'RetryAttempts': 0}, 'eventId': '0000001760944496960#92110448'}
# Deleting video analysis event: 0000001760944479914#69bb1076
#   Response: {'ResponseMetadata': {'RequestId': '78a6274b-5b40-4e23-8e87-bc0648fe14f1', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:56 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '78a6274b-5b40-4e23-8e87-bc0648fe14f1'}, 'RetryAttempts': 0}, 'eventId': '0000001760944479914#69bb1076'}
# Deleting video analysis event: 0000001760944459338#c3d235ed
#   Response: {'ResponseMetadata': {'RequestId': '0690b364-9b49-44f8-bfce-4b54a311ec3d', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 20 Oct 2025 07:26:57 GMT', 'content-type': 'application/json', 'content-length': '42', 'connection': 'keep-alive', 'x-amzn-requestid': '0690b364-9b49-44f8-bfce-4b54a311ec3d'}, 'RetryAttempts': 0}, 'eventId': '0000001760944459338#c3d235ed'}

# %%
# Verify video analysis events were deleted
remaining_video_events = memory_client.list_events(
    memory_id=video_analysis_mem_id,
    actor_id=actor_id,
    session_id=video_analysis_session_id,
    max_results=10
)
print(f"Remaining video analysis events: {len(remaining_video_events)}")
remaining_video_events
# Out:
# Remaining video analysis events: 0
# []

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
#
# 1. ✅ Basic memory creation and deletion
# 2. ✅ Context manager usage (automatic cleanup)
# 3. ✅ Multiple memory sessions
# 4. ✅ Error handling
# 5. ✅ Cleanup method
#
# ## Key Points
#
# - Memory names are automatically timestamped: `{name}_{YYYYMMDDHHMMSS}`
# - Events expire after 7 days by default (configurable)
# - Context manager ensures automatic cleanup
# - All operations are logged via component_monitor
# - Graceful error handling for all operations
